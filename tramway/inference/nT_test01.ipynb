# %%
from tramway.helper.tessellation import *
from tramway.helper.inference import *
import tramway.inference.nT_test02

trajectories = '../../examples/potential_example.trxyt'
rwa_file = 'nT_test02.rwa'

# %%
tessellate(trajectories, 'kmeans', output_file=rwa_file, force=True)

# %%
infer(rwa_file, 'nT_test02', new_cell=Locations, cell_index=1)
# Out:
# 1
# [[  6.56770000e-02   1.12704000e-01]
#  [  1.17910000e-02  -5.38770000e-02]
#  [ -5.71790000e-02  -2.01400000e-03]
#  [ -2.81030000e-02  -1.86050000e-02]
#  [  9.31980000e-02  -2.07335000e-01]
#  [  4.76130000e-02  -7.42810000e-02]
#  [ -3.42880000e-01  -7.45940000e-02]
#  [  8.82520000e-02  -2.55400000e-02]
#  [  2.51702000e-01  -1.80899000e-01]
#  [ -2.95510000e-02   9.24050000e-02]
#  [ -7.50900000e-02   1.06899000e-01]
#  [  1.67918000e-01   1.71715000e-01]
#  [  8.82980000e-02  -1.14350000e-02]
#  [  1.72983000e-01   1.32420000e-01]
#  [  8.51980000e-02  -4.62210000e-02]
#  [ -4.07450000e-02  -1.03840000e-02]
#  [  1.08992000e-01  -8.64900000e-03]
#  [ -4.85400000e-02  -1.00918000e-01]
#  [  1.07555000e-01  -3.43700000e-03]
#  [  1.24800000e-02   8.14300000e-03]
#  [  5.91900000e-02  -3.52360000e-02]
#  [  4.42550000e-02  -8.78650000e-02]
#  [ -1.78772000e-01  -3.82610000e-02]
#  [  9.81540000e-02  -1.30385000e-01]
#  [  5.79410000e-02  -1.69720000e-02]
# ...

# %%
map_plot(rwa_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-8f85059459b9> in <module>()
# ----> 1 map_plot(rwa_file)
#
# /Users/cvesterg/ownCloud/Random walks/TRamWAy/TRamWAy/tramway/helper/inference.pyc in map_plot(maps, cells, clip, output_file, fig_format, figsize, dpi, aspect, show, verbose, alpha, point_style, label, input_label, mode, **kwargs)
#     355                         warn('HDF5 libraries may not be installed', ImportWarning)
#     356                 else:
# --> 357                         cells, maps = find_artefacts(analyses, ((CellStats, Distributed), Maps), label)
#     358         if isinstance(maps, Maps):
#     359                 if mode != False:
#
# /Users/cvesterg/ownCloud/Random walks/TRamWAy/TRamWAy/tramway/core/analyses/lazy.pyc in find_artefacts(analyses, filters, labels, quantifiers, lazy, return_subtree)
# ...
