# %% [markdown]
# This notebook sets up and runs a series of analysis stages that are dispatched over the compute nodes of a multiprocessing environment, either locally (using the `multiprocessing` Python module) or remotely onto a *slurm*/*singularity* enabled computer cluster.
#
# The first 5 notebook cells show how to set up a common pipeline that is actually launched at the 6th cell of code, calling the `run` method of an `RWAnalyzer` object.
# As explained below, the first part of the notebook is dispatched and run elsewhere. The call to `run` marks where this active part stops.
# As a consequence, the notebook is structured as follows:
#
# * the first section features code cells that implement the pipeline, plus a few optional cells that should not interfere with the pipeline,
# * the second section - code cells after `a.run()` - dissects some specific parts of the pipeline and manipulate the generated output,
# * the last section gives a cleaned-up version of the sensitive part of the pipeline, to make clear which lines of code are essential.

# %% [markdown]
# # A simple *tessellate and infer* pipeline to resolve the diffusivity and effective potential in space
#
# The main difficulty in dispatching computations on remote hosts lies in locating the data files.
# An approach that has been favored in the use cases developped as of version `0.5` consists of making all the paths absolute.

# %%
import os

wd = '~/' + os.path.relpath(os.getcwd(), os.path.expanduser('~')).replace('\\', '/')
wd
# Out:
# '~/github/TRamWAy/notebooks'

# %% [markdown]
# We set up an `RWAnalyzer` object with SPT data files, the corresponding files for regions of interest,
# the segmentation to be applied to each ROI, and the inference procedure to be applied to each microdomain.

# %%
from tramway.analyzer import *

a                                 = RWAnalyzer()

a.spt_data.from_ascii_files(f'{wd}/data-examples/*.rpt.txt')
a.spt_data.localization_precision = 0.03

a.roi.from_ascii_files(suffix='roi') # => *.rpt-roi.txt

a.tesseller                       = tessellers.Hexagons

a.mapper.from_plugin('stochastic.dv')
a.mapper.diffusivity_prior        = 20
a.mapper.potential_prior          = 1
a.mapper.max_runtime              = 100 # in seconds; 100 seconds is much too short for a proper DV estimation, but convenient for a quick example
a.mapper.verbose                  = False
a.mapper.worker_count             = 4

# %% [markdown]
# Let us make sure the paths are alright.
# Of note, this notebook assumes the [introduction notebook](RWAnalyzer%20tour.ipynb) ran before, or at least its very first code cell, so that the input data are available.

# %%
a.spt_data.filepaths
# Out:
# ['/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt',
#  '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt']

# %%
[ f.roi.filepath for f in a.spt_data ]
# Out:
# ['/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt-roi.txt',
#  '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt-roi.txt']

# %% [markdown]
# Below are defined the different pipeline stages, using building blocks available in the `stages` module exported by the `tramway.analyzer` package.

# %%
a.pipeline.append_stage(stages.tessellate())
a.pipeline.append_stage(stages.reload())
a.pipeline.append_stage(stages.infer())

# %% [markdown]
# The declarative approach to setting a pipeline grants control over how to run the pipeline.
#
# The aim of such a design consisted in making such inferences run on computer clusters, in particular Slurm- and singularity-enabled clusters, communicating with these clusters through an SSH connection.
#
# At *Institut Pasteur* in Paris, France, the main computer cluster was baptised *Maestro*.
# The `environments` module exported by the `tramway.analyzer` package features a `Maestro` predefined environment that can be used to set the `env` attribute of an `RWAnalyzer` object.
#
# This environment object takes the local username to connect to the *Maestro* submit node. This can be overriden with the `username` attribute, for example in `a.env.ssh.username`.
#
# However, the Maestro cluster is accessible only over *Institut Pasteur*'s VPN or from the campus.
#
# To make this notebook run in more different circumstances, we will use the `LocalHost` environment instead.
# This environment operates in a similar fashion, but on the local computer, and does not involve any remote resource.
#
# It actually offers a convenient way to test a pipeline before running the same pipeline on a computer cluster.

# %%
#a.env                             = environments.Maestro # works only over Institut Pasteur's VPN or on campus
a.env                             = environments.LocalHost # replacement so that the demo can work anywhere
a.env.worker_count                = 10

a.env.script                      = 'RWAnalyzer standard pipeline.ipynb'

# %% [markdown]
# If someday you may export this notebook as a regular Python script, you should consider using the `__file__` variable, as demonstrated in the following code cell, as a replacement for the last line above. Otherwise, you can safely delete the following cell:

# %%
try:
    a.env.script                  = __file__
except NameError:
    # in an IPython notebook, `__file__` is not defined and there is no standard way to get the notebook's name
    a.env.script                  = 'RWAnalyzer standard pipeline.ipynb'

# %% [markdown]
# The following cell is optional. The default logging level is `INFO`.

# %%
import logging

a.logger.setLevel(logging.DEBUG)

# %% [markdown]
# The `run` method launches the pipeline.
# The workload is concentrated in the following code cell:

# %%
a.run()
# Out:
# working directory: /tmp/tmpzhd3atvm
# setup complete
# running: jupyter nbconvert --to python "/home/flaurent/github/TRamWAy/notebooks/RWAnalyzer standard pipeline.ipynb" --stdout
# initial dispatch done
# jobs ready
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=0 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt"
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=0 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt"
# jobs submitted
# setup complete
# stage 0 ready
# tessellating roi: 'roi000' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi001' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi002' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi003' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi004' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi005' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi006' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi007' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi008' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi009' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi010' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi011' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi012' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi013' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi014' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi015' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi016' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi017' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi018' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi019' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi020' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi021' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi022' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi023' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi024' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi025' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi026' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi027' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi028' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi029' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi030' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi031' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi032' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi033' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi034' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# tessellating roi: 'roi035' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt')...
# stage 0 done
# job 0 done
#
# setup complete
# stage 0 ready
# tessellating roi: 'roi000' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi001' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi002' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi003' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi004' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi005' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi006' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi007' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi008' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi009' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi010' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# tessellating roi: 'roi011' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt')...
# stage 0 done
# job 1 done
#
# jobs complete
# skipping empty file /tmp/tmpzhd3atvm/tmp3u11czw5.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpnkvr2_9h.rwa
# reading file: /tmp/tmpzhd3atvm/tmpcmu_x1xx.rwa
# reading file: /tmp/tmpzhd3atvm/tmptabx0az1.rwa
# for source file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt...
# writing file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa
# for source file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt...
# writing file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa
# results collected
# stage 1 ready
# stage 1 done
# jobs ready
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=0
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=1
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=2
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=3
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=4
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=5
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=6
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=7
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=8
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=9
# setup complete
# stage 2 ready
# inferring on roi: 'roi000' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 0 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=10
# setup complete
# stage 2 ready
# inferring on roi: 'roi001' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 1 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=11
# setup complete
# stage 2 ready
# inferring on roi: 'roi002' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 2 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=12
# setup complete
# stage 2 ready
# inferring on roi: 'roi003' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 3 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=13
# setup complete
# stage 2 ready
# inferring on roi: 'roi004' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 4 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=14
# setup complete
# stage 2 ready
# inferring on roi: 'roi005' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 5 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=15
# setup complete
# stage 2 ready
# inferring on roi: 'roi006' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 6 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=16
# setup complete
# stage 2 ready
# inferring on roi: 'roi007' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 7 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=17
# setup complete
# stage 2 ready
# inferring on roi: 'roi008' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 8 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=18
# setup complete
# stage 2 ready
# inferring on roi: 'roi009' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 9 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=19
# setup complete
# stage 2 ready
# inferring on roi: 'roi010' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 10 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=20
# setup complete
# stage 2 ready
# inferring on roi: 'roi011' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 11 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=21
# setup complete
# stage 2 ready
# inferring on roi: 'roi012' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 12 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=22
# setup complete
# stage 2 ready
# inferring on roi: 'roi013' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 13 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=23
# setup complete
# stage 2 ready
# inferring on roi: 'roi014' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 14 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=24
# setup complete
# stage 2 ready
# inferring on roi: 'roi015' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 15 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=25
# setup complete
# stage 2 ready
# inferring on roi: 'roi016' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 16 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=26
# setup complete
# stage 2 ready
# inferring on roi: 'roi017' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 17 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=27
# setup complete
# stage 2 ready
# inferring on roi: 'roi018' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 18 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=28
# setup complete
# stage 2 ready
# inferring on roi: 'roi019' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 19 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=29
# setup complete
# stage 2 ready
# inferring on roi: 'roi020' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 20 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=30
# setup complete
# stage 2 ready
# inferring on roi: 'roi021' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 21 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=31
# setup complete
# stage 2 ready
# inferring on roi: 'roi022' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 22 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=32
# setup complete
# stage 2 ready
# inferring on roi: 'roi023' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 23 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=33
# setup complete
# stage 2 ready
# inferring on roi: 'roi024' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 24 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=34
# setup complete
# stage 2 ready
# inferring on roi: 'roi025' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 25 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa" --region-index=35
# setup complete
# stage 2 ready
# inferring on roi: 'roi026' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 26 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=0
# setup complete
# stage 2 ready
# inferring on roi: 'roi027' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 27 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=1
# setup complete
# stage 2 ready
# inferring on roi: 'roi028' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 28 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=2
# setup complete
# stage 2 ready
# inferring on roi: 'roi029' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 29 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=3
# setup complete
# stage 2 ready
# inferring on roi: 'roi030' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 30 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=4
# setup complete
# stage 2 ready
# inferring on roi: 'roi031' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 31 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=5
# setup complete
# stage 2 ready
# inferring on roi: 'roi032' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 32 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=6
# setup complete
# stage 2 ready
# inferring on roi: 'roi033' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 33 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=7
# setup complete
# stage 2 ready
# inferring on roi: 'roi034' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 34 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=8
# setup complete
# stage 2 ready
# inferring on roi: 'roi035' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa')...
# stage 2 done
# job 35 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=9
# setup complete
# stage 2 ready
# inferring on roi: 'roi000' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 36 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=10
# setup complete
# stage 2 ready
# inferring on roi: 'roi001' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 37 done
#
# submitting: /usr/bin/python3 /tmp/tmpzhd3atvm/tmp6v1s338x.py --working-directory="/tmp/tmpzhd3atvm" --stage-index=1,2 --source="/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa" --region-index=11
# jobs submitted
# setup complete
# stage 2 ready
# inferring on roi: 'roi002' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 38 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi003' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 39 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi004' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 40 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi005' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 41 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi006' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 42 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi007' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 43 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi008' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 44 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi009' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 45 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi010' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 46 done
#
# setup complete
# stage 2 ready
# inferring on roi: 'roi011' (in source '/home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa')...
# stage 2 done
# job 47 done
#
# jobs complete
# skipping empty file /tmp/tmpzhd3atvm/tmp2vlbkvta.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp4223t7yg.rwa
# reading file: /tmp/tmpzhd3atvm/tmp820bghuw.rwa
# reading file: /tmp/tmpzhd3atvm/tmpp4a6t7qb.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpdq93451k.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpo_bua43x.rwa
# reading file: /tmp/tmpzhd3atvm/tmpwinh_q9t.rwa
# reading file: /tmp/tmpzhd3atvm/tmpjqfnl7li.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp_q27nfpu.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpqkdkocia.rwa
# reading file: /tmp/tmpzhd3atvm/tmpm39964xs.rwa
# reading file: /tmp/tmpzhd3atvm/tmp4tca9lti.rwa
# reading file: /tmp/tmpzhd3atvm/tmp6kn888fb.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpbv7k_3k3.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpsrlcy5p0.rwa
# reading file: /tmp/tmpzhd3atvm/tmp4q1asnt7.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpe1hai4sc.rwa
# reading file: /tmp/tmpzhd3atvm/tmpucjq5nhy.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpsua30ydh.rwa
# reading file: /tmp/tmpzhd3atvm/tmpn3w9wy0z.rwa
# reading file: /tmp/tmpzhd3atvm/tmp5dbw8u72.rwa
# reading file: /tmp/tmpzhd3atvm/tmpx9z_xnkk.rwa
# reading file: /tmp/tmpzhd3atvm/tmpcn_6tltm.rwa
# reading file: /tmp/tmpzhd3atvm/tmptgxyohat.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpe0giouf4.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp66wt5eg9.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpvng2m7ub.rwa
# reading file: /tmp/tmpzhd3atvm/tmpj5ya8b3t.rwa
# reading file: /tmp/tmpzhd3atvm/tmp59oxaf16.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpqgzje610.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpvhwirl6j.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpxfd584kn.rwa
# reading file: /tmp/tmpzhd3atvm/tmpdxppp8n5.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpqc_xsnlb.rwa
# reading file: /tmp/tmpzhd3atvm/tmpkubtydhl.rwa
# reading file: /tmp/tmpzhd3atvm/tmpfgm8cen9.rwa
# reading file: /tmp/tmpzhd3atvm/tmp1m8o8e96.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpi24oie88.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpz_g5u5ep.rwa
# reading file: /tmp/tmpzhd3atvm/tmpgz1dl4kh.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp_9o61zm9.rwa
# reading file: /tmp/tmpzhd3atvm/tmpeyw226rx.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp6bhi3bc7.rwa
# reading file: /tmp/tmpzhd3atvm/tmpcgovvcu2.rwa
# reading file: /tmp/tmpzhd3atvm/tmpf7b5vgdr.rwa
# reading file: /tmp/tmpzhd3atvm/tmpkts2epe8.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmprjgwlscf.rwa
# reading file: /tmp/tmpzhd3atvm/tmpxfsqbobi.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp2jsopy5w.rwa
# reading file: /tmp/tmpzhd3atvm/tmplzherq6e.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp8i3_1kao.rwa
# reading file: /tmp/tmpzhd3atvm/tmp17wyzx54.rwa
# reading file: /tmp/tmpzhd3atvm/tmp8ak3x669.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpqt6e6dyn.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpf5j2r5cg.rwa
# reading file: /tmp/tmpzhd3atvm/tmpan1zf9gh.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp_1qhp367.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp83dcl67q.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpa3qcz8xg.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpmaoi83za.rwa
# reading file: /tmp/tmpzhd3atvm/tmpgo_s485s.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpk86jwjp8.rwa
# reading file: /tmp/tmpzhd3atvm/tmpitzdwjl4.rwa
# reading file: /tmp/tmpzhd3atvm/tmpk0spj5gb.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp4gkkjdl6.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp1f43zs4v.rwa
# reading file: /tmp/tmpzhd3atvm/tmpmjfowj1u.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpqqxv6zcf.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp4oy4d63s.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpevnge3ff.rwa
# reading file: /tmp/tmpzhd3atvm/tmpkke8stly.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpzwn3a6_8.rwa
# reading file: /tmp/tmpzhd3atvm/tmpl5k9woml.rwa
# reading file: /tmp/tmpzhd3atvm/tmp4hxqmi41.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpcriv15bz.rwa
# reading file: /tmp/tmpzhd3atvm/tmp7bd7emq9.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpxo64ozhy.rwa
# reading file: /tmp/tmpzhd3atvm/tmpzyod7n73.rwa
# reading file: /tmp/tmpzhd3atvm/tmpykej8d_d.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpf0qe3grk.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpl5ld72xz.rwa
# reading file: /tmp/tmpzhd3atvm/tmpa7o0mnpl.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpmoee4_pc.rwa
# reading file: /tmp/tmpzhd3atvm/tmpvn2nh05r.rwa
# reading file: /tmp/tmpzhd3atvm/tmps47vmtrw.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp63b8k5a7.rwa
# reading file: /tmp/tmpzhd3atvm/tmpwpke76fs.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp8fg1j0xj.rwa
# reading file: /tmp/tmpzhd3atvm/tmpky6ap_56.rwa
# reading file: /tmp/tmpzhd3atvm/tmpuzdwoxvv.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpxdgcwvyg.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmpjti7shqp.rwa
# reading file: /tmp/tmpzhd3atvm/tmpvo3yyd4k.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp2h3lz_yx.rwa
# reading file: /tmp/tmpzhd3atvm/tmp21zfj_89.rwa
# skipping empty file /tmp/tmpzhd3atvm/tmp023lra6y.rwa
# for source file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.txt...
# writing file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-01-15ms.rpt.rwa
# for source file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.txt...
# writing file: /home/flaurent/github/TRamWAy/notebooks/data-examples/Manip01-01-Beta400AA-02-15ms.rpt.rwa
# results collected

# %% [markdown]
# At this point, the pipeline is complete. As many *.rwa* files as input SPT data files were generated both on the local and remote hosts (if different).
#
# ### Sequence diagram
#
# The procedure for distributing computations using the `LocalHost` environment is similar to (slightly simpler than) the `Maestro` environment which is a specialized `SlurmOverSSH` environment:
#
# ![Sequence diagram](SlurmOverSSH.svg)
#
# The above sequence diagram is available [here](https://sequencediagram.org/index.html#initialData=MQFQlgLgNgpgBABTABxlMA7eMAeMDGArhGAPYZwDukAFnAMpSEBOAtgPIBuMz99AEnBgZOYZuVbCIAZwBQs5AENmJfCkUYIAc3GFkcYAGEArAFEAggBEAQnABUd+oQBGrSHGlgAJjAcLlquqacABEAFJ6AJ4QPAA6GABk8RikMc6kpADWIXCK0nBh-ipgakrBIU6u7sji+DDS0jl5cAAyssJeRYFl2rr6wOhaNBDOTPAOAOqkzJk8Ht6+dl0lQRChALJ5McxwKT5N+evLpRprFUxsB3AASseroVMzc3swVxPtGJ2yYQC0AHx2FoALhu9QgATgCRuhAo5igUFkLX+YRBGGc+HI3BUiIAPD8fii4ABVaRzaT4ZgoCCydBYZSI--n5Nk3OH1UUTngnnMeLUCB0cHSOyyhaIQkiaHIEx3iCXA8JSPiGsQyDEPEzCUIoxaijA8Y0BBUGtnA7YyBAXbIPEvb9oOGgjtO45wO8U72o6zpzO8kF-Pe+HoZ4GBaLAcAAZkpo0b6dH5n0cCKqQyBuienqsvg7K9hAya4viJ7fHiPwttcWHTEe-wthM3LUh0kqaRxCABGAihQHAqHoWqmFDl4cBPswPw+I5WAuRi8JhmAoz1LIDEzla7y0j6OxukuK6Xs5dkwvEvmwNO5BwOmWY5ge1JStGnqkKwIpYPESjFDZdloRhsDSPEGg+d6volTwnj1lIFUOZhcgRQaRomqOtFHC0mkei0sZrEacCoMwLUxMEyX+YFcghQN0WnjAxFgDA3C5PCHKkH506LUJjETqpPxMsFPrCVabSmWEmnAkAA).
#
# ### Input data files are not dispatched
#
# The above diagram calls for a long explanation but, first of all, the most important point here is that scripts and executables only are dispatched, and the **input data are NOT dispatched** onto the worker side.
#
# This means that the user has to prepare the data on both the submit and worker sides.
# This includes SPT data files and ROI files.
#
# These input data files must be located (or reachable) at the same paths on both sides, which is not trivial.
# The recommended approach consists of locating the data either from the filesystem root (/) or home/user directory.
# To make absolute paths easier to translate from the local filesystem to the remote filesystem, special care was taken with the '~' shortcut that refers to the home/user directory.
#
# ### The *reload* bootstrap stage
#
# While the `tessellate` and `infer` stages have explicit goals, the `reload` stage might look optional.
# Indeed, this stage is optional if no so-called *environments* are defined.
# In this case, the stages are sequentialy run in the notebook kernel.
#
# In all the parallelizing settings, the analysis tree is updated by the `tessellate` stage only in the processes that actually ran this stage.
# On the local (or submit) side that delegates this stage, the local RWAnalyzer object is not aware of the availability of such an update.
# However, this update is required for the next stage.
# Not only is this update required for the next stage to be fed with some input, it is also required on the submit side to determine the number of and command-line arguments for the tasks that will run the `infer` stage.
#
# As a consequence, because the `tessellate` stage has updated the analysis trees in the already-existing or newly-created *.rwa* files, the `spt_data` attribute must be redefined so that it will load the updated *.rwa* files before the `infer` stage is scheduled.
#
# Unlike the `tessellate` and `infer` stages, the `reload` stage must be performed both on the submit and worker sides and is classified as a *bootstrap* stage.
# Every worker runs this bootstrap stage before running the assigned `infer` task.
#
# Note that the `reload` stage is also expected to generate significantly less workload than the other two stages.
#
# ### Stage granularity
#
# \[To be continued\]
